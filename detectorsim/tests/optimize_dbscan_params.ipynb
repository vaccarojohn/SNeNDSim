# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read NumPy data
infile_dir = 'graph_data'
data = np.load(infile_dir + '/dbscan_optimization_data.npz')

print("Successfully loaded data!")
# Out:
# Successfully loaded data!

# %%
# Total energy deposited per event (in active volume)

# Define bins
bins = np.arange(-40, 21, 1)
plt.hist(data['data'][0,0,0], bins=bins, edgecolor='black')
plt.xlim(-40, 20)

# Axis labels
plt.xlabel('Energy Deposited (MeV)')
plt.ylabel('Frequency')
plt.title('Reconstructed Energy vs. GAMPixPy Energy (at epsilon=0.6, min_samples=4)')

plt.show()

# %%
# Total energy deposited per event (in active volume)

# Define bins
bins = np.arange(-40, 21, 1)
plt.hist(data['data'][0,1,0], bins=bins, edgecolor='black')
plt.xlim(-40, 20)

# Axis labels
plt.xlabel('Energy Deposited (MeV)')
plt.ylabel('Frequency')
plt.title('Reconstructed Energy vs. GAMPixPy Energy (at epsilon=0.6, min_samples=5)')

plt.show()

# %%
# Total energy deposited per event (in active volume)

# Define bins
bins = np.arange(-40, 21, 1)
plt.hist(data['data'][1,0,0], bins=bins, edgecolor='black')
plt.xlim(-40, 20)

# Axis labels
plt.xlabel('Energy Deposited (MeV)')
plt.ylabel('Frequency')
plt.title('Reconstructed Energy vs. GAMPixPy Energy (at epsilon=0.8, min_samples=4)')

plt.show()

# %%
# Total energy deposited per event (in active volume)

# Define bins
bins = np.arange(-40, 21, 1)
plt.hist(data['data'][1,1,0], bins=bins, edgecolor='black')
plt.xlim(-40, 20)

# Axis labels
plt.xlabel('Energy Deposited (MeV)')
plt.ylabel('Frequency')
plt.title('Reconstructed Energy vs. GAMPixPy Energy (at epsilon=0.8, min_samples=5)')

plt.show()

# %%
print("Average TPC Energy Error for epsilon=0.6, min_samples=4: " + str(np.nanmean(data['data'][0,0,0])) + "MeV")
print("Average TPC Energy Error for epsilon=0.6, min_samples=5: " + str(np.nanmean(data['data'][0,1,0])) + "MeV")
print("Average TPC Energy Error for epsilon=0.8, min_samples=4: " + str(np.nanmean(data['data'][1,0,0])) + "MeV")
print("Average TPC Energy Error for epsilon=0.8, min_samples=5: " + str(np.nanmean(data['data'][1,1,0])) + "MeV")
# Out:
# Average TPC Energy Error for epsilon=0.6, min_samples=4: -6.848336024278181MeV
# Average TPC Energy Error for epsilon=0.6, min_samples=5: -10.058796772225751MeV
# Average TPC Energy Error for epsilon=0.8, min_samples=4: -6.6201090193574865MeV
# Average TPC Energy Error for epsilon=0.8, min_samples=5: -6.660702890447666MeV

# %%
print("Average LCT Energy Error for epsilon=0.6, min_samples=4: " + str(np.nanmean(data['data'][0,0,1])) + "MeV")
print("Average LCT Energy Error for epsilon=0.6, min_samples=5: " + str(np.nanmean(data['data'][0,1,1])) + "MeV")
print("Average LCT Energy Error for epsilon=0.8, min_samples=4: " + str(np.nanmean(data['data'][1,0,1])) + "MeV")
print("Average LCT Energy Error for epsilon=0.8, min_samples=5: " + str(np.nanmean(data['data'][1,1,1])) + "MeV")
# Out:
# Average LCT Energy Error for epsilon=0.6, min_samples=4: -5.850334242115022MeV
# Average LCT Energy Error for epsilon=0.6, min_samples=5: -10.228938908115056MeV
# Average LCT Energy Error for epsilon=0.8, min_samples=4: -5.624690851883628MeV
# Average LCT Energy Error for epsilon=0.8, min_samples=5: -5.645401482827687MeV

# %%
# Read NumPy data
infile_dir = 'graph_data'
data2 = np.load(infile_dir + '/dbscan_optimization_data_2.npz')

print("Successfully loaded data!")
# Out:
# Successfully loaded data!

# %%
print("Average TPC Energy Error for epsilon=0.7, min_samples=4: " + str(np.nanmean(data2['data'][0,0,0])) + "MeV")
print("Average TPC Energy Error for epsilon=0.7, min_samples=5: " + str(np.nanmean(data2['data'][0,1,0])) + "MeV")
print("Average TPC Energy Error for epsilon=0.9, min_samples=4: " + str(np.nanmean(data2['data'][1,0,0])) + "MeV")
print("Average TPC Energy Error for epsilon=0.9, min_samples=5: " + str(np.nanmean(data2['data'][1,1,0])) + "MeV")
# Out:
# Average TPC Energy Error for epsilon=0.7, min_samples=4: -6.846045551158739MeV
# Average TPC Energy Error for epsilon=0.7, min_samples=5: -10.055178462145104MeV
# Average TPC Energy Error for epsilon=0.9, min_samples=4: -6.592871909582942MeV
# Average TPC Energy Error for epsilon=0.9, min_samples=5: -6.598193950628853MeV

# %%
print("Average LCT Energy Error for epsilon=0.7, min_samples=4: " + str(np.nanmean(data2['data'][0,0,2])) + "MeV")
print("Average LCT Energy Error for epsilon=0.7, min_samples=5: " + str(np.nanmean(data2['data'][0,1,2])) + "MeV")
print("Average LCT Energy Error for epsilon=0.9, min_samples=4: " + str(np.nanmean(data2['data'][1,0,2])) + "MeV")
print("Average LCT Energy Error for epsilon=0.9, min_samples=5: " + str(np.nanmean(data2['data'][1,1,2])) + "MeV")
# Out:
# Average LCT Energy Error for epsilon=0.7, min_samples=4: -5.849336620205551MeV
# Average LCT Energy Error for epsilon=0.7, min_samples=5: -10.224305527546882MeV
# Average LCT Energy Error for epsilon=0.9, min_samples=4: -5.591193033011744MeV
# Average LCT Energy Error for epsilon=0.9, min_samples=5: -5.595959659775765MeV

# %%
# Read NumPy data
infile_dir = 'graph_data'
data3 = np.load(infile_dir + '/dbscan_optimization_data_3.npz')

print("Successfully loaded data!")
# Out:
# Successfully loaded data!

# %%
print("Average TPC Energy Error for epsilon=1, min_samples=4: " + str(np.nanmean(data3['data'][0,0,0])) + "MeV")
print("Average TPC Energy Error for epsilon=1, min_samples=5: " + str(np.nanmean(data3['data'][0,1,0])) + "MeV")
print("Average TPC Energy Error for epsilon=1.1, min_samples=4: " + str(np.nanmean(data3['data'][1,0,0])) + "MeV")
print("Average TPC Energy Error for epsilon=1.1, min_samples=5: " + str(np.nanmean(data3['data'][1,1,0])) + "MeV")
# Out:
# Average TPC Energy Error for epsilon=1, min_samples=4: -6.419743764143822MeV
# Average TPC Energy Error for epsilon=1, min_samples=5: -6.439911494513822MeV
# Average TPC Energy Error for epsilon=1.1, min_samples=4: -5.499099404086849MeV
# Average TPC Energy Error for epsilon=1.1, min_samples=5: -5.5174572147494345MeV

# %%
print("Average LTC Energy Error for epsilon=1, min_samples=4: " + str(np.nanmean(data3['data'][0,0,2])) + "MeV")
print("Average LTC Energy Error for epsilon=1, min_samples=5: " + str(np.nanmean(data3['data'][0,1,2])) + "MeV")
print("Average LTC Energy Error for epsilon=1.1, min_samples=4: " + str(np.nanmean(data3['data'][1,0,2])) + "MeV")
print("Average LTC Energy Error for epsilon=1.1, min_samples=5: " + str(np.nanmean(data3['data'][1,1,2])) + "MeV")
# Out:
# Average LTC Energy Error for epsilon=1, min_samples=4: -5.43423636596775MeV
# Average LTC Energy Error for epsilon=1, min_samples=5: -5.4411000995593275MeV
# Average LTC Energy Error for epsilon=1.1, min_samples=4: -5.270662724575157MeV
# Average LTC Energy Error for epsilon=1.1, min_samples=5: -5.289246574460243MeV

# %%
# Read NumPy data
infile_dir = 'graph_data'
data4 = np.load(infile_dir + '/dbscan_optimization_data_4.npz')

print("Successfully loaded data!")
# Out:
# Successfully loaded data!

# %%
print("Average TPC Energy Error for epsilon=0.95, min_samples=5: " + str(np.nanmean(data4['data'][0,0,0])) + "MeV")
print("Average TPC Energy Error for epsilon=0.95, min_samples=6: " + str(np.nanmean(data4['data'][0,1,0])) + "MeV")
print("Average TPC Energy Error for epsilon=1.05, min_samples=5: " + str(np.nanmean(data4['data'][1,0,0])) + "MeV")
print("Average TPC Energy Error for epsilon=1.05, min_samples=6: " + str(np.nanmean(data4['data'][1,1,0])) + "MeV")
# Out:
# Average TPC Energy Error for epsilon=0.95, min_samples=5: -6.5976285952766744MeV
# Average TPC Energy Error for epsilon=0.95, min_samples=6: -6.624863478922121MeV
# Average TPC Energy Error for epsilon=1.05, min_samples=5: -5.51764982559002MeV
# Average TPC Energy Error for epsilon=1.05, min_samples=6: -6.396132745262021MeV

# %%
print("Average LCT Energy Error for epsilon=0.95, min_samples=5: " + str(np.nanmean(data4['data'][0,0,2])) + "MeV")
print("Average LCT Energy Error for epsilon=0.95, min_samples=6: " + str(np.nanmean(data4['data'][0,1,2])) + "MeV")
print("Average LCT Energy Error for epsilon=1.05, min_samples=5: " + str(np.nanmean(data4['data'][1,0,2])) + "MeV")
print("Average LCT Energy Error for epsilon=1.05, min_samples=6: " + str(np.nanmean(data4['data'][1,1,2])) + "MeV")
# Out:
# Average LCT Energy Error for epsilon=0.95, min_samples=5: -5.595317952442376MeV
# Average LCT Energy Error for epsilon=0.95, min_samples=6: -5.624817306983801MeV
# Average LCT Energy Error for epsilon=1.05, min_samples=5: -5.289233338637849MeV
# Average LCT Energy Error for epsilon=1.05, min_samples=6: -5.404240925756654MeV

# %%
# Read NumPy data
infile_dir = 'graph_data'
data5 = np.load(infile_dir + '/dbscan_optimization_data_5.npz')

print("Successfully loaded data!")
# Out:
# Successfully loaded data!

# %%
print("Average TPC Energy Error for epsilon=0.9, min_samples=3: " + str(np.nanmean(data5['data'][0,0,0])) + "MeV")
print("Average TPC Energy Error for epsilon=0.9, min_samples=4: " + str(np.nanmean(data5['data'][0,1,0])) + "MeV")
print("Average TPC Energy Error for epsilon=1, min_samples=3: " + str(np.nanmean(data5['data'][1,0,0])) + "MeV")
print("Average TPC Energy Error for epsilon=1, min_samples=4: " + str(np.nanmean(data5['data'][1,1,0])) + "MeV")
# Out:
# Average TPC Energy Error for epsilon=0.8, min_samples=3: -5.679475375663517MeV
# Average TPC Energy Error for epsilon=0.8, min_samples=5: -6.659737692266166MeV
# Average TPC Energy Error for epsilon=1, min_samples=3: -5.51337105264819MeV
# Average TPC Energy Error for epsilon=1, min_samples=5: -6.439911494513822MeV

# %%
print("Average LCT Energy Error for epsilon=0.9, min_samples=3: " + str(np.nanmean(data5['data'][0,0,2])) + "MeV")
print("Average LCT Energy Error for epsilon=0.9, min_samples=4: " + str(np.nanmean(data5['data'][0,1,2])) + "MeV")
print("Average LCT Energy Error for epsilon=1, min_samples=3: " + str(np.nanmean(data5['data'][1,0,2])) + "MeV")
print("Average LCT Energy Error for epsilon=1, min_samples=4: " + str(np.nanmean(data5['data'][1,1,2])) + "MeV")
# Out:
# Average LCT Energy Error for epsilon=0.9, min_samples=3: -5.4267685614913335MeV
# Average LCT Energy Error for epsilon=0.9, min_samples=4: -5.591193033011744MeV
# Average LCT Energy Error for epsilon=1, min_samples=3: -5.287817004328827MeV
# Average LCT Energy Error for epsilon=1, min_samples=4: -5.43423636596775MeV

# %%
print("Average Extra Segments Number for epsilon=0.9, min_samples=3: " + str(np.nanmean(data6['data'][0,0,9])))
print("Average Extra Segments Number for epsilon=0.9, min_samples=4: " + str(np.nanmean(data5['data'][0,1,9])))
print("Average Extra Segments Number for epsilon=1, min_samples=3: " + str(np.nanmean(data5['data'][1,0,9])))
print("Average Extra Segments Number for epsilon=1, min_samples=4: " + str(np.nanmean(data5['data'][1,1,9])))
# Out:
# Average Extra Segments Number for epsilon=0.9, min_samples=3: 1.1285
# Average Extra Segments Number for epsilon=0.9, min_samples=4: 1.1245
# Average Extra Segments Number for epsilon=1, min_samples=3: 1.386
# Average Extra Segments Number for epsilon=1, min_samples=4: 1.3755

# %%
print("Average Lacking Segments Number for epsilon=0.9, min_samples=3: " + str(np.nanmean(data5['data'][0,0,8])))
print("Average Lacking Segments Number for epsilon=0.9, min_samples=4: " + str(np.nanmean(data5['data'][0,1,8])))
print("Average Lacking Segments Number for epsilon=1, min_samples=3: " + str(np.nanmean(data5['data'][1,0,8])))
print("Average Lacking Segments Number for epsilon=1, min_samples=4: " + str(np.nanmean(data5['data'][1,1,8])))
# Out:
# Average Lacking Segments Number for epsilon=0.9, min_samples=3: 0.4149
# Average Lacking Segments Number for epsilon=0.9, min_samples=4: 0.4961
# Average Lacking Segments Number for epsilon=1, min_samples=3: 0.4193
# Average Lacking Segments Number for epsilon=1, min_samples=4: 0.4891

# %%
print("LCT Efficiency for epsilon=0.9, min_samples=3: " + str(np.nanmean((data5['data'][0,0,10] - data5['data'][0,0,8])/data5['data'][0,0,10])))
print("LCT Efficiency for epsilon=0.9, min_samples=4: " + str(np.nanmean((data5['data'][0,1,10] - data5['data'][0,1,8])/data5['data'][0,1,10])))
print("LCT Efficiency for epsilon=1, min_samples=3: " + str(np.nanmean((data5['data'][1,0,10] - data5['data'][1,0,8])/data5['data'][1,0,10])))
print("LCT Efficiency for epsilon=1, min_samples=4: " + str(np.nanmean((data5['data'][1,1,10] - data5['data'][1,1,8])/data5['data'][1,1,10])))
# Out:
# LCT Efficiency for epsilon=0.9, min_samples=3: 0.9824848199377672
# LCT Efficiency for epsilon=0.9, min_samples=4: 0.9798209701888205
# LCT Efficiency for epsilon=1, min_samples=3: 0.9824243190710462
# LCT Efficiency for epsilon=1, min_samples=4: 0.98004034589176

# %%
# Read NumPy data
infile_dir = 'graph_data'
data6 = np.load(infile_dir + '/dbscan_optimization_data_6.npz')

print("Successfully loaded data!")
# Out:
# Successfully loaded data!

# %%
print("Average TPC Energy Error for epsilon=0.8, min_samples=3: " + str(np.nanmean(data6['data'][0,0,0])) + "MeV")
print("Average TPC Energy Error for epsilon=0.8, min_samples=5: " + str(np.nanmean(data6['data'][0,1,0])) + "MeV")
print("Average TPC Energy Error for epsilon=1, min_samples=3: " + str(np.nanmean(data6['data'][1,0,0])) + "MeV")
print("Average TPC Energy Error for epsilon=1, min_samples=5: " + str(np.nanmean(data6['data'][1,1,0])) + "MeV")
# Out:
# Average TPC Energy Error for epsilon=0.8, min_samples=3: -5.679475375663517MeV
# Average TPC Energy Error for epsilon=0.8, min_samples=5: -6.659737692266166MeV
# Average TPC Energy Error for epsilon=1, min_samples=3: -5.51337105264819MeV
# Average TPC Energy Error for epsilon=1, min_samples=5: -6.439911494513822MeV

# %%
print("Average LTC Energy Error for epsilon=0.8, min_samples=3: " + str(np.nanmean(data6['data'][0,0,2])) + "MeV")
print("Average LTC Energy Error for epsilon=0.8, min_samples=5: " + str(np.nanmean(data6['data'][0,1,2])) + "MeV")
print("Average LTC Energy Error for epsilon=1, min_samples=3: " + str(np.nanmean(data6['data'][1,0,2])) + "MeV")
print("Average LTC Energy Error for epsilon=1, min_samples=5: " + str(np.nanmean(data6['data'][1,1,2])) + "MeV")
# Out:
# Average LTC Energy Error for epsilon=0.8, min_samples=3: -5.476701757605451MeV
# Average LTC Energy Error for epsilon=0.8, min_samples=5: -5.645401482827687MeV
# Average LTC Energy Error for epsilon=1, min_samples=3: -5.287817004328827MeV
# Average LTC Energy Error for epsilon=1, min_samples=5: -5.4411000995593275MeV

# %%
print("LCT Efficiency for epsilon=0.8, min_samples=3: " + str(np.nanmean((data6['data'][0,0,10] - data6['data'][0,0,8])/data6['data'][0,0,10])))
print("LCT Efficiency for epsilon=0.8, min_samples=5: " + str(np.nanmean((data6['data'][0,1,10] - data6['data'][0,1,8])/data6['data'][0,1,10])))
print("LCT Efficiency for epsilon=1, min_samples=3: " + str(np.nanmean((data6['data'][1,0,10] - data6['data'][1,0,8])/data6['data'][1,0,10])))
print("LCT Efficiency for epsilon=1, min_samples=5: " + str(np.nanmean((data6['data'][1,1,10] - data6['data'][1,1,8])/data6['data'][1,1,10])))
# Out:
# LCT Efficiency for epsilon=0.8, min_samples=3: 0.9821672638197831
# LCT Efficiency for epsilon=0.8, min_samples=5: 0.978936981699377
# LCT Efficiency for epsilon=1, min_samples=3: 0.9824243190710462
# LCT Efficiency for epsilon=1, min_samples=5: 0.9797714270230171

# %%
print("LCT Purity for epsilon=0.8, min_samples=3: " + str(np.nanmean((data6['data'][0,0,11] - data6['data'][0,0,9])/data6['data'][0,0,11])))
print("LCT Purity for epsilon=0.8, min_samples=5: " + str(np.nanmean((data6['data'][0,1,11] - data6['data'][0,1,9])/data6['data'][0,1,11])))
print("LCT Purity for epsilon=1, min_samples=3: " + str(np.nanmean((data6['data'][1,0,11] - data6['data'][1,0,9])/data6['data'][1,0,11])))
print("LCT Purity for epsilon=1, min_samples=5: " + str(np.nanmean((data6['data'][1,1,11] - data6['data'][1,1,9])/data6['data'][1,1,11])))
# Out:
# LCT Purity for epsilon=0.8, min_samples=3: 0.9623645284545699
# LCT Purity for epsilon=0.8, min_samples=5: 0.9622730320176431
# LCT Purity for epsilon=1, min_samples=3: 0.952754375517756
# LCT Purity for epsilon=1, min_samples=5: 0.9528913063032771

# %%
# Read NumPy data
infile_dir = 'graph_data'
data7 = np.load(infile_dir + '/dbscan_optimization_data_7.npz')

print("Successfully loaded data!")
# Out:
# Successfully loaded data!

# %%
# Read NumPy data
infile_dir = 'graph_data'
data7 = np.load(infile_dir + '/dbscan_optimization_data_7.npz')
data8 = np.load(infile_dir + '/dbscan_optimization_data_8.npz')

print("Successfully loaded data!")
# Out:
# Successfully loaded data!

# %%
print("LCT Efficiency for epsilon=0.55, min_samples=3: " + str(np.nanmean((data7['data'][3,0,10] - data7['data'][3,0,8])/data7['data'][3,0,10])))
print("LCT Efficiency for epsilon=0.6, min_samples=3: " + str(np.nanmean((data8['data'][0,0,10] - data8['data'][0,0,8])/data8['data'][0,0,10])))
print("LCT Efficiency for epsilon=0.65, min_samples=3: " + str(np.nanmean((data8['data'][1,0,10] - data8['data'][1,0,8])/data8['data'][1,0,10])))
print("LCT Efficiency for epsilon=0.7, min_samples=3: " + str(np.nanmean((data8['data'][2,0,10] - data8['data'][2,0,8])/data8['data'][2,0,10])))
# Out:
# LCT Efficiency for epsilon=0.55, min_samples=3: 0.9808559234495128
# LCT Efficiency for epsilon=0.6, min_samples=3: 0.9808559234495128
# LCT Efficiency for epsilon=0.65, min_samples=3: 0.9808559234495128
# LCT Efficiency for epsilon=0.7, min_samples=3: 0.9808559234495128

# %%
print("LCT Purity for epsilon=0.55, min_samples=3: " + str(np.nanmean((data7['data'][3,0,11] - data7['data'][3,0,9])/data7['data'][3,0,11])))
print("LCT Purity for epsilon=0.6, min_samples=3: " + str(np.nanmean((data8['data'][0,0,11] - data8['data'][0,0,9])/data8['data'][0,0,11])))
print("LCT Purity for epsilon=0.65, min_samples=3: " + str(np.nanmean((data8['data'][1,0,11] - data8['data'][1,0,9])/data8['data'][1,0,11])))
print("LCT Purity for epsilon=0.7, min_samples=3: " + str(np.nanmean((data8['data'][2,0,11] - data8['data'][2,0,9])/data8['data'][2,0,11])))
# Out:
# LCT Purity for epsilon=0.55, min_samples=3: 0.9718333513878028
# LCT Purity for epsilon=0.6, min_samples=3: 0.9718313513878027
# LCT Purity for epsilon=0.65, min_samples=3: 0.9718243001057514
# LCT Purity for epsilon=0.7, min_samples=3: 0.9718243001057514

# %%
print("Average LTC Energy Error for epsilon=0.55, min_samples=3: " + str(np.nanmean(data7['data'][3,0,3])))
print("Average LTC Energy Error for epsilon=0.6, min_samples=3: " + str(np.nanmean(data8['data'][0,0,3])))
print("Average LTC Energy Error for epsilon=0.65, min_samples=3: " + str(np.nanmean(data8['data'][1,0,3])))
print("Average LTC Energy Error for epsilon=0.7, min_samples=3: " + str(np.nanmean(data8['data'][2,0,3])))
# Out:
# Average LTC Energy Error for epsilon=0.55, min_samples=3: -0.26911022085249503
# Average LTC Energy Error for epsilon=0.6, min_samples=3: -0.26911001531930384
# Average LTC Energy Error for epsilon=0.65, min_samples=3: -0.26910928060164446
# Average LTC Energy Error for epsilon=0.7, min_samples=3: -0.26910928060164446

# %%
print("Average TPC Energy Error for epsilon=0.55, min_samples=3: " + str(np.nanmean(data7['data'][3,0,1])))
print("Average TPC Energy Error for epsilon=0.6, min_samples=3: " + str(np.nanmean(data8['data'][0,0,1])))
print("Average TPC Energy Error for epsilon=0.65, min_samples=3: " + str(np.nanmean(data8['data'][1,0,1])))
print("Average TPC Energy Error for epsilon=0.7, min_samples=3: " + str(np.nanmean(data8['data'][2,0,1])))
# Out:
# Average TPC Energy Error for epsilon=0.55, min_samples=3: -0.22566961549818915
# Average TPC Energy Error for epsilon=0.6, min_samples=3: -0.2256662811927629
# Average TPC Energy Error for epsilon=0.65, min_samples=3: -0.2256621164462629
# Average TPC Energy Error for epsilon=0.7, min_samples=3: -0.22566203703282187

# %%
# LTC Energy Reconstruction

# Define bins
bins = np.arange(-1, 1.02, 0.02)
plt.hist(data8['data'][2,0,3], bins=bins, edgecolor='black')
plt.xlim(-1, 1)

# Axis labels
plt.xlabel('Reconstructed Energy Difference')
plt.ylabel('Frequency')
plt.title('LCT Energy Reconstruction (at epsilon=0.7, min_samples=3)')

plt.show()

# %%
# TPC Energy Reconstruction

# Define bins
bins = np.arange(-1, 1.02, 0.02)
plt.hist(data8['data'][2,0,1], bins=bins, edgecolor='black')
plt.xlim(-1, 1)

# Axis labels
plt.xlabel('Reconstructed Energy Difference')
plt.ylabel('Frequency')
plt.title('TPC Energy Reconstruction (at epsilon=0.7, min_samples=3)')

plt.show()

# %%
# Read NumPy data
infile_dir = 'graph_data'
final_data = np.load(infile_dir + '/dbscan_final_data.npz')

print("Successfully loaded data!")
# Out:
# Successfully loaded data!

# %%
print("Average TPC Energy (DBSCAN) for epsilon=0.7, min_samples=3: " + str(np.nanmean(final_data['data'][0,0,0])) + "MeV")
print("Average TPC Energy (GAMPixPy) for epsilon=0.7, min_samples=3: " + str(np.nanmean(final_data['data'][0,0,1])) + "MeV")
print("Average TPC Energy (EdepSim) for epsilon=0.7, min_samples=3: " + str(np.nanmean(final_data['data'][0,0,2])) + "MeV")
print("Average TPC Energy Difference (DBSCAN vs. GAMPixPy) for epsilon=0.7, min_samples=3: " + str(np.nanmean((final_data['data'][0,0,0] - final_data['data'][0,0,1])/final_data['data'][0,0,1])))
print("Average TPC Energy Difference (DBSCAN vs. EdepSim) for epsilon=0.7, min_samples=3: " + str(np.nanmean((final_data['data'][0,0,0] - final_data['data'][0,0,2])/final_data['data'][0,0,2])))
print("Average TPC Energy Difference (GAMPixPy vs. EdepSim) for epsilon=0.7, min_samples=3: " + str(np.nanmean((final_data['data'][0,0,1] - final_data['data'][0,0,2])/final_data['data'][0,0,2])))
# Out:
# Average TPC Energy (DBSCAN) for epsilon=0.7, min_samples=3: 19.578493335547236MeV
# Average TPC Energy (GAMPixPy) for epsilon=0.7, min_samples=3: 25.449223849043012MeV
# Average TPC Energy (EdepSim) for epsilon=0.7, min_samples=3: 28.002144609320165MeV
# Average TPC Energy Difference (DBSCAN vs. GAMPixPy) for epsilon=0.7, min_samples=3: -0.22566203703282187
# Average TPC Energy Difference (DBSCAN vs. EdepSim) for epsilon=0.7, min_samples=3: -0.2985273622995135
# Average TPC Energy Difference (GAMPixPy vs. EdepSim) for epsilon=0.7, min_samples=3: -0.09653561520544865

# %%
print("Average LTC Energy (DBSCAN) for epsilon=0.7, min_samples=3: " + str(np.nanmean(final_data['data'][0,0,3])) + "MeV")
print("Average LTC Energy (GAMPixPy) for epsilon=0.7, min_samples=3: " + str(np.nanmean(final_data['data'][0,0,4])) + "MeV")
print("Average LTC Energy (EdepSim) for epsilon=0.7, min_samples=3: " + str(np.nanmean(final_data['data'][0,0,5])) + "MeV")
print("Average LTC Energy Difference (DBSCAN vs. GAMPixPy) for epsilon=0.7, min_samples=3: " + str(np.nanmean((final_data['data'][0,0,3] - final_data['data'][0,0,4])/final_data['data'][0,0,4])))
print("Average LTC Energy Difference (DBSCAN vs. EdepSim) for epsilon=0.7, min_samples=3: " + str(np.nanmean((final_data['data'][0,0,3] - final_data['data'][0,0,5])/final_data['data'][0,0,5])))
print("Average LTC Energy Difference (GAMPixPy vs. EdepSim) for epsilon=0.7, min_samples=3: " + str(np.nanmean((final_data['data'][0,0,4] - final_data['data'][0,0,5])/final_data['data'][0,0,5])))
# Out:
# Average LTC Energy (DBSCAN) for epsilon=0.7, min_samples=3: 16.179442865056657MeV
# Average LTC Energy (GAMPixPy) for epsilon=0.7, min_samples=3: 21.86883701047481MeV
# Average LTC Energy (EdepSim) for epsilon=0.7, min_samples=3: 18.288751497721673MeV
# Average LTC Energy Difference (DBSCAN vs. GAMPixPy) for epsilon=0.7, min_samples=3: -0.26910928060164446
# Average LTC Energy Difference (DBSCAN vs. EdepSim) for epsilon=0.7, min_samples=3: -0.12220158752362517
# Average LTC Energy Difference (GAMPixPy vs. EdepSim) for epsilon=0.7, min_samples=3: 0.20828696361327212

# %%
print("Average LTC Center X-Position (DBSCAN vs. GAMPixPy) for epsilon=0.7, min_samples=3: " + str(np.nanmean(final_data['data'][0,0,6] - final_data['data'][0,0,7])) + "cm")
print("Average LTC Center X-Position (DBSCAN vs. EdepSim) for epsilon=0.7, min_samples=3: " + str(np.nanmean(final_data['data'][0,0,6] - final_data['data'][0,0,8])) + "cm")
print("Average LTC Center X-Position (GAMPixPy vs. Edepsim) for epsilon=0.7, min_samples=3: " + str(np.nanmean(final_data['data'][0,0,7] - final_data['data'][0,0,8])) + "cm")
# Out:
# Average LTC Center X-Position (DBSCAN vs. GAMPixPy) for epsilon=0.7, min_samples=3: -1.2032875861487327cm
# Average LTC Center X-Position (DBSCAN vs. EdepSim) for epsilon=0.7, min_samples=3: -1.2040363812052854cm
# Average LTC Center X-Position (GAMPixPy vs. Edepsim) for epsilon=0.7, min_samples=3: -0.0007487950565526524cm

# %%
print("Average LTC Center Y-Position (DBSCAN vs. GAMPixPy) for epsilon=0.7, min_samples=3: " + str(np.nanmean(final_data['data'][0,0,9] - final_data['data'][0,0,10])) + "cm")
print("Average LTC Center Y-Position (DBSCAN vs. EdepSim) for epsilon=0.7, min_samples=3: " + str(np.nanmean(final_data['data'][0,0,9] - final_data['data'][0,0,11])) + "cm")
print("Average LTC Center Y-Position (GAMPixPy vs. Edepsim) for epsilon=0.7, min_samples=3: " + str(np.nanmean(final_data['data'][0,0,10] - final_data['data'][0,0,11])) + "cm")
# Out:
# Average LTC Center Y-Position (DBSCAN vs. GAMPixPy) for epsilon=0.7, min_samples=3: -0.018903770622877694cm
# Average LTC Center Y-Position (DBSCAN vs. EdepSim) for epsilon=0.7, min_samples=3: -0.007145117610090204cm
# Average LTC Center Y-Position (GAMPixPy vs. Edepsim) for epsilon=0.7, min_samples=3: 0.011758653012787487cm

# %%
print("Average LTC Center Z-Position (DBSCAN vs. GAMPixPy) for epsilon=0.7, min_samples=3: " + str(np.nanmean(final_data['data'][0,0,12] - final_data['data'][0,0,13])) + "cm")
print("Average LTC Center Z-Position (DBSCAN vs. EdepSim) for epsilon=0.7, min_samples=3: " + str(np.nanmean(final_data['data'][0,0,12] - final_data['data'][0,0,14])) + "cm")
print("Average LTC Center Z-Position (GAMPixPy vs. Edepsim) for epsilon=0.7, min_samples=3: " + str(np.nanmean(final_data['data'][0,0,13] - final_data['data'][0,0,14])) + "cm")
# Out:
# Average LTC Center Z-Position (DBSCAN vs. GAMPixPy) for epsilon=0.7, min_samples=3: 0.015605731854482576cm
# Average LTC Center Z-Position (DBSCAN vs. EdepSim) for epsilon=0.7, min_samples=3: 0.011251549614046044cm
# Average LTC Center Z-Position (GAMPixPy vs. Edepsim) for epsilon=0.7, min_samples=3: -0.0043541822404365264cm

# %%
print("Average LTC Center T-Position (DBSCAN vs. GAMPixPy) for epsilon=0.7, min_samples=3: " + str(np.nanmean(final_data['data'][0,0,15] - final_data['data'][0,0,16])) + "us")
print("Average LTC Center T-Position (DBSCAN vs. EdepSim) for epsilon=0.7, min_samples=3: " + str(np.nanmean(final_data['data'][0,0,15] - final_data['data'][0,0,17])) + "us")
print("Average LTC Center T-Position (GAMPixPy vs. Edepsim) for epsilon=0.7, min_samples=3: " + str(np.nanmean(final_data['data'][0,0,16] - final_data['data'][0,0,17])) + "us")
# Out:
# Average LTC Center T-Position (DBSCAN vs. GAMPixPy) for epsilon=0.7, min_samples=3: 0.29548122315318354us
# Average LTC Center T-Position (DBSCAN vs. EdepSim) for epsilon=0.7, min_samples=3: 111.70156731916us
# Average LTC Center T-Position (GAMPixPy vs. Edepsim) for epsilon=0.7, min_samples=3: 111.40608609600682us

# %%
print("Average LTC Efficiency (DBSCAN vs. GamPixPy) for epsilon=0.7, min_samples=3: " + str(np.nanmean((final_data['data'][0,0,25] - final_data['data'][0,0,18])/final_data['data'][0,0,25])))
print("Average LTC Efficiency (DBSCAN vs. EdepSim) for epsilon=0.7, min_samples=3: " + str(np.nanmean((final_data['data'][0,0,26] - final_data['data'][0,0,20])/final_data['data'][0,0,26])))
print("Average LTC Efficiency (GAMPixPy vs. EdepSim) for epsilon=0.7, min_samples=3: " + str(np.nanmean((final_data['data'][0,0,26] - final_data['data'][0,0,23])/final_data['data'][0,0,26])))
# Out:
# Average LTC Efficiency (DBSCAN vs. GamPixPy) for epsilon=0.7, min_samples=3: 0.9808559234495128
# Average LTC Efficiency (DBSCAN vs. EdepSim) for epsilon=0.7, min_samples=3: 0.9812140752806495
# Average LTC Efficiency (GAMPixPy vs. EdepSim) for epsilon=0.7, min_samples=3: 0.9817846132381528

# %%
print("Average LTC Purity (DBSCAN vs. GamPixPy) for epsilon=0.7, min_samples=3: " + str(np.nanmean((final_data['data'][0,0,24] - final_data['data'][0,0,19])/final_data['data'][0,0,24])))
print("Average LTC Purity (DBSCAN vs. EdepSim) for epsilon=0.7, min_samples=3: " + str(np.nanmean((final_data['data'][0,0,24] - final_data['data'][0,0,21])/final_data['data'][0,0,24])))
print("Average LTC Purity (GAMPixPy vs. EdepSim) for epsilon=0.7, min_samples=3: " + str(np.nanmean((final_data['data'][0,0,25] - final_data['data'][0,0,22])/final_data['data'][0,0,25])))
# Out:
# Average LTC Purity (DBSCAN vs. GamPixPy) for epsilon=0.7, min_samples=3: 0.9718243001057514
# Average LTC Purity (DBSCAN vs. EdepSim) for epsilon=0.7, min_samples=3: 0.5439704601011155
# Average LTC Purity (GAMPixPy vs. EdepSim) for epsilon=0.7, min_samples=3: 0.5495894387167328

# %%
# TPC Energy Reconstruction

# Define bins
bins = np.arange(-1, 1.02, 0.02)
plt.hist((final_data['data'][0,0,0] - final_data['data'][0,0,2])/final_data['data'][0,0,2], bins=bins, edgecolor='black')
plt.xlim(-1, 1)

# Axis labels
plt.xlabel('Reconstructed Energy Difference (DBSCAN vs. EdepSim)')
plt.ylabel('Frequency')
plt.title('TPC Energy Reconstruction (at epsilon=0.7, min_samples=3)')

plt.show()

# %%
# TPC Energy Reconstruction

# Define bins
bins = np.arange(-1, 1.02, 0.02)
plt.hist((final_data['data'][0,0,0] - final_data['data'][0,0,1])/final_data['data'][0,0,1], bins=bins, edgecolor='black')
plt.xlim(-1, 1)

# Axis labels
plt.xlabel('Reconstructed Energy Difference (DBSCAN vs. GAMPixPy)')
plt.ylabel('Frequency')
plt.title('TPC Energy Reconstruction (at epsilon=0.7, min_samples=3)')

plt.show()

# %%
# TPC Energy Reconstruction

# Define bins
bins = np.arange(-1, 1.02, 0.02)
plt.hist((final_data['data'][0,0,1] - final_data['data'][0,0,2])/final_data['data'][0,0,2], bins=bins, edgecolor='black')
plt.xlim(-1, 1)

# Axis labels
plt.xlabel('Reconstructed Energy Difference (GAMPixPy vs. EdepSim)')
plt.ylabel('Frequency')
plt.title('TPC Energy Reconstruction (at epsilon=0.7, min_samples=3)')

plt.show()

# %%
# LTC Energy Reconstruction

# Define bins
bins = np.arange(-1, 1.02, 0.02)
plt.hist((final_data['data'][0,0,3] - final_data['data'][0,0,5])/final_data['data'][0,0,5], bins=bins, edgecolor='black')
plt.xlim(-1, 1)

# Axis labels
plt.xlabel('Reconstructed Energy Difference (DBSCAN vs. EdepSim)')
plt.ylabel('Frequency')
plt.title('LCT Energy Reconstruction (at epsilon=0.7, min_samples=3)')

plt.show()

# %%
# LTC Energy Reconstruction

# Define bins
bins = np.arange(-1, 1.02, 0.02)
plt.hist((final_data['data'][0,0,3] - final_data['data'][0,0,4])/final_data['data'][0,0,4], bins=bins, edgecolor='black')
plt.xlim(-1, 1)

# Axis labels
plt.xlabel('Reconstructed Energy Difference (DBSCAN vs. GAMPixPy)')
plt.ylabel('Frequency')
plt.title('LCT Energy Reconstruction (at epsilon=0.7, min_samples=3)')

plt.show()

# %%
# LTC Energy Reconstruction

# Define bins
bins = np.arange(-1, 1.02, 0.02)
plt.hist((final_data['data'][0,0,4] - final_data['data'][0,0,5])/final_data['data'][0,0,5], bins=bins, edgecolor='black')
plt.xlim(-1, 1)

# Axis labels
plt.xlabel('Reconstructed Energy Difference (GAMPixPy vs. EdepSim)')
plt.ylabel('Frequency')
plt.title('LCT Energy Reconstruction (at epsilon=0.7, min_samples=3)')

plt.show()

# %%
# LTC Efficiency Reconstruction

# Define bins
bins = np.arange(0, 1.01, 0.01)
plt.hist((final_data['data'][0,0,26] - final_data['data'][0,0,20])/final_data['data'][0,0,26], bins=bins, edgecolor='black')
plt.xlim(0, 1)

# Axis labels
plt.xlabel('Efficiency (DBSCAN vs. EdepSim)')
plt.ylabel('Frequency')
plt.title('LCT Efficiency (at epsilon=0.7, min_samples=3)')

plt.show()

# %%
# LTC Purity Reconstruction

# Define bins
bins = np.arange(0, 1.01, 0.01)
plt.hist((final_data['data'][0,0,24] - final_data['data'][0,0,21])/final_data['data'][0,0,24], bins=bins, edgecolor='black')
plt.xlim(0, 1)

# Axis labels
plt.xlabel('Purity (DBSCAN vs. EdepSim)')
plt.ylabel('Frequency')
plt.title('LCT Purity (at epsilon=0.7, min_samples=3)')

plt.show()
