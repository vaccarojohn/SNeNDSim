# %%
import h5py
import matplotlib.pyplot as plt
import numpy as np

# %%
# Read NumPy data
infile_dir = 'graph_data'
data = np.load(infile_dir + '/signal_selection_data.npz')

print("Successfully loaded data!")
# Out:
# Successfully loaded data!

# %%
# Proton with highest energy deposition (in active volume)

# Define bins
bins = np.arange(0, 12.25, 0.25)
plt.hist(data['pmaxe'], bins=bins, edgecolor='black')
plt.xlim(0, 12)

# Axis labels
plt.xlabel('Energy Deposited (MeV)')
plt.ylabel('Frequency')
plt.title('Proton with Highest Energy Deposition (in Active Volume)')

plt.show()

# %%
# Energy deposited in CRT volume per event

# Define bins
bins = np.arange(0, 10.25, 0.25)
plt.hist(data['crt'], bins=bins, edgecolor='black')
plt.xlim(0, 10)

# Axis labels
plt.xlabel('Energy Deposited (MeV)')
plt.ylabel('Frequency')
plt.title('Energy Deposited in CRT')

plt.show()

# %%
# Lowest segment timestamp

# Define bins
bins = np.arange(0, 2, 1)
plt.hist(data['light'], bins=bins, edgecolor='black')
plt.xlim(0, 3)

# Axis labels
plt.xlabel('Timestamp (us)')
plt.ylabel('Frequency')
plt.title('Lowest Energy Deposition Timestamp')

plt.show()

# %%
# Read NumPy data
infile_dir = 'graph_data'
data2 = np.load(infile_dir + '/signal_selection_data_new.npz')

print("Successfully loaded data!")
# Out:
# Successfully loaded data!

# %%
# tmin graph

# Define bins
bins = np.arange(0, 0.01005, 0.0005)
plt.hist(data2['tmin'], bins=bins, edgecolor='black')
plt.xlim(0, 0.01)

# Axis labels
plt.xlabel('Timestamp (us)')
plt.ylabel('Frequency')
plt.title('tmin')

plt.show()

# %%
# tmax graph

# Define bins
bins = np.arange(0, 0.01005, 0.0005)
plt.hist(data2['tmax'], bins=bins, edgecolor='black')
plt.xlim(0, 0.01)

# Axis labels
plt.xlabel('Timestamp (us)')
plt.ylabel('Frequency')
plt.title('tmax')

plt.show()

# %%
# trms graph

# Define bins
bins = np.arange(0, 0.01005, 0.0005)
plt.hist(data2['trms'], bins=bins, edgecolor='black')
plt.xlim(0, 0.01)

# Axis labels
plt.xlabel('Timestamp (us)')
plt.ylabel('Frequency')
plt.title('trms')

plt.show()

# %%
# tseg graph

# Define bins
bins = np.arange(0, 0.01005, 0.0005)
plt.hist(data2['tseg'], bins=bins, edgecolor='black')
plt.xlim(0, 0.01)

# Axis labels
plt.xlabel('Timestamp (us)')
plt.ylabel('Frequency')
plt.title('max(tend - tstart)')

plt.show()

# %%
# tdiff graph

# Define bins
bins = np.arange(0, 0.01005, 0.0005)
plt.hist(data2['tdiff'], bins=bins, edgecolor='black')
plt.xlim(0, 0.01)

# Axis labels
plt.xlabel('Timestamp (us)')
plt.ylabel('Frequency')
plt.title('tmax - tmin')

plt.show()
